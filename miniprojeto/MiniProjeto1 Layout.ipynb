# %% [markdown]
# ___
# # MINIPROJETO 1

# %% [markdown]
# ## <font color='red'>Matheus de S. Pamplona Silva</font>
# ___

# %% [markdown]
# ## <font color='blue'>Ocorrências do sistema aéreo brasileiro.</font>

# %% [markdown]
# ___
# ### Itens 1 a 3 - Resolução:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import stats

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Matheus\Desktop\Ciencia dos dados

# %%
novo = pd.read_excel('Pasta1.xlsx', sep=',')

# %%
novo["ano"] = novo.ano.astype('float')
n = novo.ano.shape[0]
ut0 = ((novo.ano.value_counts()/n)*100).round(decimals=1)
print(ut0)
faixa2= range(2005,2016,1)
freq2=pd.cut(novo.ano,faixa2)
a2=freq2.value_counts()
plot =novo.ano.plot.hist(bins=faixa2,color=('m'))
# Out:
# 2012.0    14.2
# 2013.0    13.3
# 2011.0    12.6
# 2014.0    12.4
# 2015.0    11.0
# 2010.0     9.6
# 2009.0     7.7
# 2008.0     7.3
# 2007.0     6.2
# 2006.0     5.8
# Name: ano, dtype: float64

# %% [markdown]
# ___
# ### Itens 4 a 6 - Resolução:

# %% [markdown]
# O histograma descrito possui simetria a esquerda.
#
# curva semelhante a curva exponpow e beta

# %%
mu_exp = novo.ano.mean()
gamma = 2
theta_gamma = novo.ano.mean()/gamma
print(theta_gamma)

x = np.linspace(0, 2016, 2016)

fig = plt.figure(figsize=(14,10))

faixa2= range(2005,2016,1)
freq2=pd.cut(novo.ano,faixa2)
a2=freq2.value_counts()
#plot =novo.ano.plot.hist(bins=faixa2,color=('m'))
#exponencial = stats.expon.pdf(x, scale=mu_exp)
#expo = stats.exponpow.pdf(x, 1000, scale=12000, loc=0)
#gamma = stats.gamma.pdf(x, scale=theta_gamma, loc=0, a=gamma)


#plt.plot(x, expo, '-', color='green', label="exponpon") # Plota a gamma teórica
#plt.plot(x, exponencial, '-', color='red', label="Exponencial") # Plota a exponencial teórica
#plt.xlim(2000,2016)
#plt.legend()


a = 0.001
k_gama = 1

b = 1000
teta_gama = novo.ano.mean()/k_gama

novo.ano.plot(kind='hist', bins=faixa2, normed=True, legend=False)
expo = stats.exponpow.pdf(x, b, scale=2016, loc=0)
beta = stats.beta.pdf(x, k_gama, a, scale=2016, loc=1)

plt.plot(x,expo, '-', color='green', label="expo")
plt.xlim(2005,2016)
plt.plot(x,beta, '-', color='yellow', label="beta")

plt.legend()
# Out:
# 1005.6070547607302

# %% [markdown]
# ___
# ### Itens 7 a 9 - Resolução:

# %% [markdown]
# Professora, eu realmente não consegui desenvolver este projeto, para mim, pouco do conteúdo necessário para esta atividade foi absorvido, e venho ressaltar que grande dessa defasagem é minha culpa. Espero que para o projeto final eu possa realizar uma melhora considerável.
#
# Grato, Matheus Pamplona

# %% [markdown]
# ___
# ### Itens 10 e 11 - Resolução:
